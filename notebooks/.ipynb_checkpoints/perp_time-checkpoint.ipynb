# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('perpData.csv', header=[0])

# %%
data
# Out:
#                                            trader  avg_hours_between  \
# 0      \xde2e9a97961b3221740ebdb4f3f8baa7de0f85bb           0.000000
# 1      \xdf8ddc7512762c8ee27de320edea3041a8beec4b           0.000000
# 2      \x28425420e14f52ece14dcf786cf85e273313610c           0.000000
# 3      \xdf854c2466966a9b791bc111b0d5aa848db2d50f           0.000000
# 4      \xde5bfd1c9317b5625fa5d60bddde6ff01d40886f           0.000000
# ...                                           ...                ...
# 13635  \x91d46a68324991f2e96f121317b642a8d4179190           0.033799
# 13636  \x16b1aa595b8ee725aee23a9d4ceac2163d80db64           0.019547
# 13637  \xf77ca96962bc48d6ff7b10f35ef2f504a287b3a1           0.027614
# 13638  \x66465ad392942e78f8147ae565a43f174071822b           0.026788
# 13639  \x7462da033c5cceb21691d2447af34f3e333e0b85           0.017160
#
#        median_mins  max_days_between  num_obs       last_active  \
# 0         0.000000          0.000000        1   2022-05-27 8:09
# ...

# %%
data.describe()
# Out:
#        avg_hours_between    median_mins  max_days_between        num_obs
# count       13640.000000   13640.000000      13640.000000   13640.000000
# mean          243.684168   13299.748578         15.400571     259.769355
# std           584.985652   35081.586487         30.331695    4410.174390
# min             0.000000       0.000000          0.000000       1.000000
# 25%             0.014167       0.383333          0.000764       1.000000
# 50%             0.361528       5.483333          0.028299       1.000000
# 75%            75.531014    1306.658334         10.530955       3.000000
# max          4582.114167  274926.850000        190.921424  155661.000000
